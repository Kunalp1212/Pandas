# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\DELL\\Downloads'

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option("display.max_rows",205) #to display all the rows
pd.set_option("display.max_columns",15) #to display all the columns

# %%
#To read or load csv file

Auto=pd.read_csv("Automobile_data.csv")

# %%
Auto
# Out:
#      symboling normalized-losses           make fuel-type   body-style  \
# 0            3                 ?    alfa-romero       gas  convertible
# 1            3                 ?    alfa-romero       gas  convertible
# 2            1                 ?    alfa-romero       gas    hatchback
# 3            2               164           audi       gas        sedan
# 4            2               164           audi       gas        sedan
# 5            2                 ?           audi       gas        sedan
# 6            1               158           audi       gas        sedan
# 7            1                 ?           audi       gas        wagon
# 8            1               158           audi       gas        sedan
# 9            0                 ?           audi       gas    hatchback
# 10           2               192            bmw       gas        sedan
# 11           0               192            bmw       gas        sedan
# ...

# %%
Auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# ...

# %%
Auto.shape
# Out:
# (205, 15)

# %%
Auto["make"].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
for col in Auto:
    print(col,":",Auto[col].unique())
    print("**************************************************************")
# Out:
# symboling : [ 3  1  2  0 -1 -2]
# **************************************************************
# normalized-losses : ['?' '164' '158' '192' '188' '121' '98' '81' '118' '148' '110' '145' '137'
#  '101' '78' '106' '85' '107' '104' '113' '150' '129' '115' '93' '142'
#  '161' '153' '125' '128' '122' '103' '168' '108' '194' '231' '119' '154'
#  '74' '186' '83' '102' '89' '87' '77' '91' '134' '65' '197' '90' '94'
#  '256' '95']
# **************************************************************
# make : ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
# **************************************************************
# fuel-type : ['gas' 'diesel']
# **************************************************************
# body-style : ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# ...

# %%
#to check count of cars each fuel wise 

Auto["fuel-type"].value_counts()
# Out:
# fuel-type
# gas       185
# diesel     20
# Name: count, dtype: int64

# %%
#Filter out Gas fuel type 

GAS=Auto[Auto["fuel-type"]=="gas"]

# %%
GAS.shape
# Out:
# (185, 15)

# %%
GAS
# Out:
#      symboling normalized-losses           make fuel-type   body-style  \
# 0            3                 ?    alfa-romero       gas  convertible
# 1            3                 ?    alfa-romero       gas  convertible
# 2            1                 ?    alfa-romero       gas    hatchback
# 3            2               164           audi       gas        sedan
# 4            2               164           audi       gas        sedan
# 5            2                 ?           audi       gas        sedan
# 6            1               158           audi       gas        sedan
# 7            1                 ?           audi       gas        wagon
# 8            1               158           audi       gas        sedan
# 9            0                 ?           audi       gas    hatchback
# 10           2               192            bmw       gas        sedan
# 11           0               192            bmw       gas        sedan
# ...

# %%
#Filter out diesel fuel type data

DIESELDATA=Auto[Auto["fuel-type"]=="diesel"]

# %%
DIESELDATA.shape
# Out:
# (20, 15)

# %%
DIESELDATA
# Out:
#      symboling normalized-losses           make fuel-type body-style  \
# 63           0                 ?          mazda    diesel      sedan
# 66           0                 ?          mazda    diesel      sedan
# 67          -1                93  mercedes-benz    diesel      sedan
# 68          -1                93  mercedes-benz    diesel      wagon
# 69           0                93  mercedes-benz    diesel    hardtop
# 70          -1                93  mercedes-benz    diesel      sedan
# 90           1               128         nissan    diesel      sedan
# 108          0               161         peugot    diesel      sedan
# 110          0                 ?         peugot    diesel      wagon
# 112          0               161         peugot    diesel      sedan
# 114          0                 ?         peugot    diesel      wagon
# 116          0               161         peugot    diesel      sedan
# 158          0                91         toyota    diesel      sedan
# ...

# %%
#Find count of cars maker wise

Auto["make"].value_counts()
# Out:
# make
# toyota           32
# nissan           18
# mazda            17
# mitsubishi       13
# honda            13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# mercedes-benz     8
# bmw               8
# audi              7
# plymouth          7
# saab              6
# porsche           5
# isuzu             4
# jaguar            3
# chevrolet         3
# alfa-romero       3
# renault           2
# mercury           1
# Name: count, dtype: int64

# %%
#Find the highest price of car

print("HIGHEST PRICE OF CAR:",Auto["price"].max())
# Out:
# HIGHEST PRICE OF CAR: 45400

# %%
#Finding max price row

Auto["price"].idxmax() #idxmax ====index of max value
# Out:
# 74

# %%
#After finding index of max price find whole detail about the car

Auto.iloc[74]
# Out:
# symboling                        1
# normalized-losses                ?
# make                 mercedes-benz
# fuel-type                      gas
# body-style                 hardtop
# drive-wheels                   rwd
# engine-location              front
# width                         72.0
# height                        55.4
# engine-type                   ohcv
# engine-size                    304
# horsepower                     184
# city-mpg                        14
# highway-mpg                     16
# price                        45400
# Name: 74, dtype: object

# %%
#Lowest price car

Auto["price"].min()
# Out:
# 5118

# %%
#find the lowest price index

Auto["price"].idxmin()
# Out:
# 138

# %%
#find the detail in row of min price car

Auto.iloc[138:139,0:] #rowindex ,column index
# Out:
#      symboling normalized-losses    make fuel-type body-style drive-wheels  \
# 138          2                83  subaru       gas  hatchback          fwd
#
#     engine-location  width  height engine-type  engine-size horsepower  \
# 138           front   63.4    53.7        ohcf           97         69
#
#      city-mpg  highway-mpg  price
# 138        31           36   5118

# %%
#total valuation of all cars in my data

Auto["price"].sum()
# Out:
# 2711633

# %%
#Find the sum of price of all diesel cars

Auto[Auto["fuel-type"]=="diesel"].sum()
# Out:
# symboling                                                            2
# normalized-losses             ??93939393128161?161?1619191651229494?95
# make                 mazdamazdamercedes-benzmercedes-benzmercedes-b...
# fuel-type            dieseldieseldieseldieseldieseldieseldieseldies...
# body-style           sedansedansedanwagonhardtopsedansedansedanwago...
# drive-wheels         fwdrwdrwdrwdrwdrwdfwdrwdrwdrwdrwdrwdfwdfwdfwdf...
# engine-location      frontfrontfrontfrontfrontfrontfrontfrontfrontf...
# width                                                           1348.6
# height                                                          1116.7
# engine-type          ohcohcohcohcohcohcohclllllohcohcohcohcohcohcoh...
# engine-size                                                       2714
# horsepower               647212312312312355959595959556567352526868106
# city-mpg                                                           606
# ...

# %%
print("SUM of all Diesel Cars price:",DIESELDATA["price"].sum())
# Out:
# SUM of all Diesel Cars price: 316763

# %%
#What is total price for each category of maker?

#groupby

Auto.groupby("make")["price"].sum()
# Out:
# make
# alfa-romero       46495
# audi             119155
# bmw              208950
# chevrolet         18021
# dodge             70879
# honda            106401
# isuzu             50833
# jaguar           103800
# mazda            181099
# mercedes-benz    269176
# mercury           16503
# mitsubishi       120117
# nissan           187482
# peugot           170380
# plymouth          55744
# porsche          137602
# renault           19190
# saab              91340
# subaru           102495
# toyota           316346
# volkswagen       120930
# volvo            198695
# Name: price, dtype: int64

# %%
#FUEL TYPE wise total price

Auto.groupby("fuel-type")["price"].sum()
# Out:
# fuel-type
# diesel     316763
# gas       2394870
# Name: price, dtype: int64

# %%
#Average price of car by body-style

print("Average Price as per body-style",Auto.groupby("body-style")["price"].mean())
# Out:
# Average Price as per body-style body-style
# convertible    21890.500000
# hardtop        22208.500000
# hatchback      10015.800000
# sedan          14502.260417
# wagon          12371.960000
# Name: price, dtype: float64

# %%
#Min price of car by engine type

Auto.groupby("engine-type")["price"].min()
# Out:
# engine-type
# dohc      9298
# dohcv    12000
# l         5151
# ohc       5195
# ohcf      5118
# ohcv     13499
# rotor    10945
# Name: price, dtype: int64

# %%
#to check average highway-mpg of all fuel type

Auto.groupby("fuel-type")["highway-mpg"].mean()
# Out:
# fuel-type
# diesel    34.750000
# gas       30.318919
# Name: highway-mpg, dtype: float64

# %%
#Find total price of cars body style and fuel type

Auto.groupby(["body-style","fuel-type"])["price"].sum()
# Out:
# body-style   fuel-type
# convertible  gas           131343
# hardtop      diesel         28176
#              gas           149492
# hatchback    diesel          7788
#              gas           693318
# sedan        diesel        221616
#              gas          1170601
# wagon        diesel         59183
#              gas           250116
# Name: price, dtype: int64

# %%
#What is average highway-mpg given by each maker & fuel type under them?

Auto.groupby(["make","fuel-type"])["highway-mpg"].mean()
# Out:
# make           fuel-type
# alfa-romero    gas          26.666667
# audi           gas          24.142857
# bmw            gas          25.375000
# chevrolet      gas          46.333333
# dodge          gas          34.111111
# honda          gas          35.461538
# isuzu          gas          36.000000
# jaguar         gas          18.333333
# mazda          diesel       40.500000
#                gas          30.800000
# mercedes-benz  diesel       25.000000
#                gas          17.000000
# mercury        gas          24.000000
# mitsubishi     gas          31.153846
# nissan         diesel       50.000000
#                gas          31.941176
# peugot         diesel       29.800000
#                gas          24.000000
# plymouth       gas          34.142857
# porsche        gas          26.000000
# renault        gas          31.000000
# saab           gas          27.333333
# subaru         gas          30.750000
# toyota         diesel       38.666667
# ...

# %%
#Pick out all the BMW cars with highway mpg more than 25

Auto[(Auto["make"]=="bmw")&(Auto["highway-mpg"]>25)]

#we are giving 2 conditions inside the DataFrame ==Auto[one for extracting bmw 
#and second for extracting data more than 25 highway mpg from bmw
# Out:
#     symboling normalized-losses make fuel-type body-style drive-wheels  \
# 10          2               192  bmw       gas      sedan          rwd
# 11          0               192  bmw       gas      sedan          rwd
# 12          0               188  bmw       gas      sedan          rwd
# 13          0               188  bmw       gas      sedan          rwd
#
#    engine-location  width  height engine-type  engine-size horsepower  \
# 10           front   64.8    54.3         ohc          108        101
# 11           front   64.8    54.3         ohc          108        101
# 12           front   64.8    54.3         ohc          164        121
# 13           front   64.8    54.3         ohc          164        121
#
#     city-mpg  highway-mpg  price
# 10        23           29  16430
# 11        23           29  16925
# 12        21           28  20970
# 13        21           28  21105

# %%
#Pick out the data having fuel type gas or having highway mpg >30

Auto[(Auto["fuel-type"]=="gas")|(Auto["highway-mpg"]>30)]
# Out:
#      symboling normalized-losses           make fuel-type   body-style  \
# 0            3                 ?    alfa-romero       gas  convertible
# 1            3                 ?    alfa-romero       gas  convertible
# 2            1                 ?    alfa-romero       gas    hatchback
# 3            2               164           audi       gas        sedan
# 4            2               164           audi       gas        sedan
# 5            2                 ?           audi       gas        sedan
# 6            1               158           audi       gas        sedan
# 7            1                 ?           audi       gas        wagon
# 8            1               158           audi       gas        sedan
# 9            0                 ?           audi       gas    hatchback
# 10           2               192            bmw       gas        sedan
# 11           0               192            bmw       gas        sedan
# ...

# %%
#DELETING UNWANTED COLUMN===drop ===axis=1===column
#axis=0 ===rows

#Deleting an unwanted symboling

Auto.drop("symboling",axis=1)
#This code only drop the column and just gives the output 
#if we check our data again we will be able to see all the column as it is.
# Out:
#     normalized-losses           make fuel-type   body-style drive-wheels  \
# 0                   ?    alfa-romero       gas  convertible          rwd
# 1                   ?    alfa-romero       gas  convertible          rwd
# 2                   ?    alfa-romero       gas    hatchback          rwd
# 3                 164           audi       gas        sedan          fwd
# 4                 164           audi       gas        sedan          4wd
# 5                   ?           audi       gas        sedan          fwd
# 6                 158           audi       gas        sedan          fwd
# 7                   ?           audi       gas        wagon          fwd
# 8                 158           audi       gas        sedan          fwd
# 9                   ?           audi       gas    hatchback          4wd
# 10                192            bmw       gas        sedan          rwd
# 11                192            bmw       gas        sedan          rwd
# ...

# %%
Auto
# Out:
#      symboling normalized-losses           make fuel-type   body-style  \
# 0            3                 ?    alfa-romero       gas  convertible
# 1            3                 ?    alfa-romero       gas  convertible
# 2            1                 ?    alfa-romero       gas    hatchback
# 3            2               164           audi       gas        sedan
# 4            2               164           audi       gas        sedan
# 5            2                 ?           audi       gas        sedan
# 6            1               158           audi       gas        sedan
# 7            1                 ?           audi       gas        wagon
# 8            1               158           audi       gas        sedan
# 9            0                 ?           audi       gas    hatchback
# 10           2               192            bmw       gas        sedan
# 11           0               192            bmw       gas        sedan
# ...

# %%
#Droping the column permanently from data

Auto=Auto.drop("symboling",axis=1)

#The above code should be only once..
#if we try to run it again we will get erroe because the column is already dropped

# %%
Auto
# Out:
#     normalized-losses           make fuel-type   body-style drive-wheels  \
# 0                   ?    alfa-romero       gas  convertible          rwd
# 1                   ?    alfa-romero       gas  convertible          rwd
# 2                   ?    alfa-romero       gas    hatchback          rwd
# 3                 164           audi       gas        sedan          fwd
# 4                 164           audi       gas        sedan          4wd
# 5                   ?           audi       gas        sedan          fwd
# 6                 158           audi       gas        sedan          fwd
# 7                   ?           audi       gas        wagon          fwd
# 8                 158           audi       gas        sedan          fwd
# 9                   ?           audi       gas    hatchback          4wd
# 10                192            bmw       gas        sedan          rwd
# 11                192            bmw       gas        sedan          rwd
# ...

# %%
#Dropping multiple columns together

NEWAUTO=Auto.drop(["drive-wheels","engine-location","width","height"],axis=1)

# %%
NEWAUTO
# Out:
#     normalized-losses           make fuel-type   body-style engine-type  \
# 0                   ?    alfa-romero       gas  convertible        dohc
# 1                   ?    alfa-romero       gas  convertible        dohc
# 2                   ?    alfa-romero       gas    hatchback        ohcv
# 3                 164           audi       gas        sedan         ohc
# 4                 164           audi       gas        sedan         ohc
# 5                   ?           audi       gas        sedan         ohc
# 6                 158           audi       gas        sedan         ohc
# 7                   ?           audi       gas        wagon         ohc
# 8                 158           audi       gas        sedan         ohc
# 9                   ?           audi       gas    hatchback         ohc
# 10                192            bmw       gas        sedan         ohc
# 11                192            bmw       gas        sedan         ohc
# ...

# %%
#Deleting unwanted rows===axis=0

Auto.drop(5,axis=0) #this will just generate output
# Out:
#     normalized-losses           make fuel-type   body-style drive-wheels  \
# 0                   ?    alfa-romero       gas  convertible          rwd
# 1                   ?    alfa-romero       gas  convertible          rwd
# 2                   ?    alfa-romero       gas    hatchback          rwd
# 3                 164           audi       gas        sedan          fwd
# 4                 164           audi       gas        sedan          4wd
# 6                 158           audi       gas        sedan          fwd
# 7                   ?           audi       gas        wagon          fwd
# 8                 158           audi       gas        sedan          fwd
# 9                   ?           audi       gas    hatchback          4wd
# 10                192            bmw       gas        sedan          rwd
# 11                192            bmw       gas        sedan          rwd
# 12                188            bmw       gas        sedan          rwd
# ...

# %%
Auto=Auto.drop(5,axis=0) 
#this will delete the row permanently and store in the variable

# %%
Auto
# Out:
#     normalized-losses           make fuel-type   body-style drive-wheels  \
# 0                   ?    alfa-romero       gas  convertible          rwd
# 1                   ?    alfa-romero       gas  convertible          rwd
# 2                   ?    alfa-romero       gas    hatchback          rwd
# 3                 164           audi       gas        sedan          fwd
# 4                 164           audi       gas        sedan          4wd
# 6                 158           audi       gas        sedan          fwd
# 7                   ?           audi       gas        wagon          fwd
# 8                 158           audi       gas        sedan          fwd
# 9                   ?           audi       gas    hatchback          4wd
# 10                192            bmw       gas        sedan          rwd
# 11                192            bmw       gas        sedan          rwd
# 12                188            bmw       gas        sedan          rwd
# ...

# %%
Auto=Auto.drop([14,15,16,17],axis=0)

#multiple rows deleting

# %%
Auto
# Out:
#     normalized-losses           make fuel-type   body-style drive-wheels  \
# 0                   ?    alfa-romero       gas  convertible          rwd
# 1                   ?    alfa-romero       gas  convertible          rwd
# 2                   ?    alfa-romero       gas    hatchback          rwd
# 3                 164           audi       gas        sedan          fwd
# 4                 164           audi       gas        sedan          4wd
# 6                 158           audi       gas        sedan          fwd
# 7                   ?           audi       gas        wagon          fwd
# 8                 158           audi       gas        sedan          fwd
# 9                   ?           audi       gas    hatchback          4wd
# 10                192            bmw       gas        sedan          rwd
# 11                192            bmw       gas        sedan          rwd
# 12                188            bmw       gas        sedan          rwd
# ...

# %%
#RENAMING THE COLUMN HEADERS

Auto.rename(columns={"make":"Manufacturer"},inplace=True)

# %%
Auto
# Out:
#     normalized-losses   Manufacturer fuel-type   body-style drive-wheels  \
# 0                   ?    alfa-romero       gas  convertible          rwd
# 1                   ?    alfa-romero       gas  convertible          rwd
# 2                   ?    alfa-romero       gas    hatchback          rwd
# 3                 164           audi       gas        sedan          fwd
# 4                 164           audi       gas        sedan          4wd
# 6                 158           audi       gas        sedan          fwd
# 7                   ?           audi       gas        wagon          fwd
# 8                 158           audi       gas        sedan          fwd
# 9                   ?           audi       gas    hatchback          4wd
# 10                192            bmw       gas        sedan          rwd
# 11                192            bmw       gas        sedan          rwd
# 12                188            bmw       gas        sedan          rwd
# ...

# %%
Auto.shape
# Out:
# (200, 14)

# %%
#REMOVING DUPLICATES

Auto=Auto.drop_duplicates() #This will delete all the duplicate rows

# %%
Auto.shape

#As the shape remains same of data that means there were no duplicates in the data
# Out:
# (200, 14)

# %%
#To keep atleast one unique row which is needed in data 
#we have to drop other duplicates of such unique data

Auto=Auto.drop_duplicates(keep="first")

#To keep first entry as it is and delete other same entries

# %%
Auto.shape
# Out:
# (200, 14)

# %% [markdown]
# JOINS

# %%
#Creating DF1 with dictionary

dict1={"Name":["Pooja","Ketan","Jinal","Hiren","Tina","Leena"],
       "SQL":[45,50,65,43,42,41]}
DF1=pd.DataFrame(dict1)
DF1
# Out:
#     Name  SQL
# 0  Pooja   45
# 1  Ketan   50
# 2  Jinal   65
# 3  Hiren   43
# 4   Tina   42
# 5  Leena   41

# %%
dict2={"Name":["Mohan","Pooja","Tina","Payal","Reena","Jinal","Leena","Umesh"],
       "Python":[55,60,75,42,55,58,69,56]}
DF2=pd.DataFrame(dict2)
DF2
# Out:
#     Name  Python
# 0  Mohan      55
# 1  Pooja      60
# 2   Tina      75
# 3  Payal      42
# 4  Reena      55
# 5  Jinal      58
# 6  Leena      69
# 7  Umesh      56

# %%
#MERGING both DF on the basis common columns Name

DF3=pd.merge(DF1,DF2,on="Name") 
#by default inner join will get perform on the basis of common column
DF3
#inner join means only matching rows from both DF will seen in the output
# Out:
#     Name  SQL  Python
# 0  Pooja   45      60
# 1  Jinal   65      58
# 2   Tina   42      75
# 3  Leena   41      69

# %%
#Full outer ===Means match & unmatched data from both DF

DF4=pd.merge(DF1,DF2,on="Name",how="outer")
DF4
#In front of unmatched data we can see Nan Values
# Out:
#     Name   SQL  Python
# 0  Pooja  45.0    60.0
# 1  Ketan  50.0     NaN
# 2  Jinal  65.0    58.0
# 3  Hiren  43.0     NaN
# 4   Tina  42.0    75.0
# 5  Leena  41.0    69.0
# 6  Mohan   NaN    55.0
# 7  Payal   NaN    42.0
# 8  Reena   NaN    55.0
# 9  Umesh   NaN    56.0

# %%
#LEFT OUTER JOIN

DF5=pd.merge(DF1,DF2,on="Name",how="left")
DF5
# Out:
#     Name  SQL  Python
# 0  Pooja   45    60.0
# 1  Ketan   50     NaN
# 2  Jinal   65    58.0
# 3  Hiren   43     NaN
# 4   Tina   42    75.0
# 5  Leena   41    69.0

# %%
#Right JOin
DF6=pd.merge(DF1,DF2,on="Name",how="right")
DF6
# Out:
#     Name   SQL  Python
# 0  Mohan   NaN      55
# 1  Pooja  45.0      60
# 2   Tina  42.0      75
# 3  Payal   NaN      42
# 4  Reena   NaN      55
# 5  Jinal  65.0      58
# 6  Leena  41.0      69
# 7  Umesh   NaN      56
